# %%
'''
1. extract total fov of PN, but exclude pointsources, clusters centers(~ 0.5 r200c), and the chip edge
2. exclude all the point sources in the events files and check the images generated by the events
3. extract the spectrum from the region exclude chip edge and the cluster centers
4. repeat for two observations

'''
